# %%
import pandas as pd

# %%
movie_data = pd.read_csv('../cleaned_data.csv')
movie_data.head()
# Out:
#    Unnamed: 0  id  release_date                  movie  production_budget  \
# 0           2  80  Jul 10, 2015            The Gallows             100000
# 1          25  12   Jan 6, 2012       The Devil Inside            1000000
# 2          51  65  Oct 20, 2010  Paranormal Activity 2            3000000
# 3          59  49  Feb 24, 2017                Get Out            5000000
# 4          65  64  Oct 21, 2016              Moonlight            1500000
#
#    domestic_gross  worldwide_gross  worldwide_roi roi_category  \
# 0        22764410         41656474   41656.474000         high
# 1        53262945        101759490   10175.949000         high
# 2        84752907        177512032    5917.067733         high
# 3       176040665        255367951    5107.359020         high
# 4        27854931         65245512    4349.700800         high
#
#                      movie_year     tconst          primary_title  \
# 0            The Gallows (2015)  tt2309260            The Gallows
# ...

# %%
movie_data.drop("Unnamed: 0", axis=1, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-7-8b2e18086ef1> in <module>
# ----> 1 movie_data.drop("Unnamed: 0", axis=1, inplace=True)
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3938                                            index=index, columns=columns,
#    3939                                            level=level, inplace=inplace,
# -> 3940                                            errors=errors)
#    3941
#    3942     @rewrite_axis_style_signature('mapper', [('copy', True),
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3778         for axis, labels in axes.items():
#    3779             if labels is not None:
# ...

# %%
movie_data.set_index("id", inplace=True)
movie_data.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2656             try:
# -> 2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'id'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-11-033dcc2a5f95> in <module>
# ----> 1 movie_data.set_index("id", inplace=True)
# ...

# %%
movie_data.to_csv(r'../movie_data.csv')

# %%
movie_data2 = pd.read_csv('../movie_data.csv')
movie_data2.head()
# Out:
#    id  release_date                  movie  production_budget  domestic_gross  \
# 0  80  Jul 10, 2015            The Gallows             100000        22764410
# 1  12   Jan 6, 2012       The Devil Inside            1000000        53262945
# 2  65  Oct 20, 2010  Paranormal Activity 2            3000000        84752907
# 3  49  Feb 24, 2017                Get Out            5000000       176040665
# 4  64  Oct 21, 2016              Moonlight            1500000        27854931
#
#    worldwide_gross  worldwide_roi roi_category                    movie_year  \
# 0         41656474   41656.474000         high            The Gallows (2015)
# 1        101759490   10175.949000         high       The Devil Inside (2012)
# 2        177512032    5917.067733         high  Paranormal Activity 2 (2010)
# 3        255367951    5107.359020         high                Get Out (2017)
# 4         65245512    4349.700800         high              Moonlight (2016)
#
# ...
