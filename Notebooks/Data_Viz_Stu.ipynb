# %%
import numpy as np
import pandas as pd
# %matplotlib notebook
import matplotlib.pyplot as plt
import seaborn as sns

# %%
cleaned_data = pd.read_csv('cleaned_data.csv')

# %%
cleaned_data.head()
# Out:
#    Unnamed: 0  id  release_date                  movie  production_budget  \
# 0           2  80  Jul 10, 2015            The Gallows             100000
# 1          25  12   Jan 6, 2012       The Devil Inside            1000000
# 2          51  65  Oct 20, 2010  Paranormal Activity 2            3000000
# 3          59  49  Feb 24, 2017                Get Out            5000000
# 4          65  64  Oct 21, 2016              Moonlight            1500000
#
#    domestic_gross  worldwide_gross  worldwide_roi roi_category  \
# 0        22764410         41656474   41656.474000         high
# 1        53262945        101759490   10175.949000         high
# 2        84752907        177512032    5917.067733         high
# 3       176040665        255367951    5107.359020         high
# 4        27854931         65245512    4349.700800         high
#
#                      movie_year     tconst          primary_title  \
# 0            The Gallows (2015)  tt2309260            The Gallows
# ...

# %%
cleaned_data.loc[cleaned_data['genres'] == 'Action,Adventure,Sci-Fi']
# Out:
#       Unnamed: 0  id  release_date                                  movie  \
# 121          514  38  Mar 23, 2012                       The Hunger Games
# 142          607  13  Jun 22, 2018         Jurassic World: Fallen Kingdom
# 144          609  34  Jun 12, 2015                         Jurassic World
# 167          695   7  Apr 27, 2018                 Avengers: Infinity War
# 173          709  27   May 4, 2012                           The Avengers
# 174          710  42  Feb 16, 2018                          Black Panther
# 176          722  38  Nov 22, 2013        The Hunger Games: Catching Fire
# 183          755  96   Mar 8, 2019                         Captain Marvel
# 196          797  62  Nov 21, 2014  The Hunger Games: Mockingjay - Part 1
# 198          804  48   May 3, 2013                             Iron Man 3
# 212          860  64  Jun 29, 2011         Transformers: Dark of the Moon
# 248          970  37  Jun 27, 2014        Transformers: Age of Extinction
# ...

# %%
piv3 = pd.pivot_table(cleaned_data, index='genres', values='worldwide_roi')
piv3
# Out:
#                               worldwide_roi
# genres
# Action                            92.071520
# Action,Adventure                   0.261644
# Action,Adventure,Animation       368.360984
# Action,Adventure,Biography       247.584996
# Action,Adventure,Comedy          393.798725
# Action,Adventure,Crime           218.645859
# Action,Adventure,Drama           185.833441
# Action,Adventure,Family          164.336324
# Action,Adventure,Fantasy         249.463533
# Action,Adventure,Horror          324.953089
# Action,Adventure,Mystery         164.736120
# Action,Adventure,Romance         155.419903
# Action,Adventure,Sci-Fi          373.457514
# Action,Adventure,Thriller        273.830083
# Action,Adventure,Western         100.726999
# Action,Animation,Comedy          290.366994
# Action,Biography,Comedy          271.138424
# Action,Biography,Crime             8.813242
# Action,Biography,Documentary       0.364400
# Action,Biography,Drama           687.794396
# ...

# %%
sns.violinplot(cleaned_data.genres, cleaned_data.worldwide_roi).
# Out:
# <img src="data:image/png;base64,..." width="640">
